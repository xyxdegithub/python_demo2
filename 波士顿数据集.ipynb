# %%
import tensorflow as tf

# %%
# CRIM：城镇人均犯罪率。
# ZN：住宅用地超过 25000 sq.ft. 的比例。
# INDUS：城镇非零售商用土地的比例。
# CHAS：查理斯河空变量（如果边界是河流，则为1；否则为0）。
# NOX：一氧化氮浓度。
# RM：住宅平均房间数。
# AGE：1940 年之前建成的自用房屋比例。
# DIS：到波士顿五个中心区域的加权距离。
# RAD：辐射性公路的接近指数。
# TAX：每 10000 美元的全值财产税率。
# PTRATIO：城镇师生比例。
# B：1000（Bk-0.63）^ 2，其中 Bk 指代城镇中黑人的比例。
# LSTAT：人口中地位低下者的比例。
# MEDV：自住房的平均房价，以千美元计。
boston_housing=tf.keras.datasets.boston_housing

# %%
(train_x,train_y),(test_x,test_y)=boston_housing.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/boston_housing.npz
# 57344/57026 [==============================] - 0s 6us/step
# 65536/57026 [==================================] - 0s 5us/step

# %%
#默认情况下
#训练集有404条数据
#测试集有102条数据
print(len(train_x))
print(len(test_x))
# Out:
# 404
# 102

# %%
print(train_x.shape) #train_x中有13条属性
# Out:
# (404, 13)

# %%
print(train_x)
# Out:
# [[1.23247e+00 0.00000e+00 8.14000e+00 ... 2.10000e+01 3.96900e+02
#   1.87200e+01]
#  [2.17700e-02 8.25000e+01 2.03000e+00 ... 1.47000e+01 3.95380e+02
#   3.11000e+00]
#  [4.89822e+00 0.00000e+00 1.81000e+01 ... 2.02000e+01 3.75520e+02
#   3.26000e+00]
#  ...
#  [3.46600e-02 3.50000e+01 6.06000e+00 ... 1.69000e+01 3.62250e+02
#   7.83000e+00]
#  [2.14918e+00 0.00000e+00 1.95800e+01 ... 1.47000e+01 2.61950e+02
#   1.57900e+01]
#  [1.43900e-02 6.00000e+01 2.93000e+00 ... 1.56000e+01 3.76700e+02
#   4.38000e+00]]

# %%
print(train_x[:,10])
# Out:
# [21.  14.7 20.2 20.2 20.2 19.6 20.2 14.7 14.7 21.2 20.2 20.2 16.6 20.2
#  19.1 20.2 20.2 14.8 14.7 20.9 20.2 18.3 17.  15.3 20.2 20.2 15.2 17.8
#  21.  19.2 16.6 20.2 20.2 21.  18.3 19.6 21.  21.  19.6 18.7 20.1 17.9
#  20.2 20.2 20.2 21.  21.2 21.  13.  20.2 20.2 20.2 17.4 16.6 14.7 19.1
#  20.2 20.2 17.6 16.6 19.1 18.6 20.2 20.9 20.2 20.2 21.2 20.2 20.2 18.6
#  17.9 20.2 15.2 18.4 21.  15.2 20.2 21.2 19.7 14.7 16.  13.  21.  15.3
#  21.2 20.2 20.2 14.7 14.7 20.2 20.2 14.7 16.  17.8 18.  16.6 17.  18.5
